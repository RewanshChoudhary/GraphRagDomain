# %%
import sys
sys.path.insert(0, "/home/rewansh57/Programming/GraphRagForMovies/graphrag-entertainment")

from ingestion.sentence_splitter import split_sentences

# Test 1: Normal text
result = split_sentences("Hello world. How are you? I am fine!")
print("Test 1:", result)
assert result == ["Hello world.", "How are you?", "I am fine!"], f"FAIL: {result}"

# Test 2: Empty string
result = split_sentences("")
print("Test 2:", result)
assert result == [], f"FAIL: {result}"

# Test 3: No punctuation
result = split_sentences("No punctuation here")
print("Test 3:", result)
assert result == ["No punctuation here"], f"FAIL: {result}"

# Test 4: Multiple punctuation types
result = split_sentences("First! Second? Third.")
print("Test 4:", result)
assert result == ["First!", "Second?", "Third."], f"FAIL: {result}"

print("All tests passed!")
# Out:
# Test 1: ['Hello world.', 'How are you?', 'I am fine!']
# Test 2: []
# Test 3: ['No punctuation here']
# Test 4: ['First!', 'Second?', 'Third.']
# All tests passed!
